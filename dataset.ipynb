# %% [markdown]
# <a href="https://colab.research.google.com/github/peanutjh/FinalProject/blob/%EC%88%98%EA%B8%B8/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
DATA_PATH = '/content/drive/MyDrive/2조_누구냐, 넌!/04. 기타자료/인플루언서 분류 최종/'

# %%
influencer_list_1 = pd.read_excel(f"{DATA_PATH}1차 인플루언서 리스트.xlsx")
influencer_list_2 = pd.read_excel(f"{DATA_PATH}2차 인플루언서 리스트.xlsx")
ad_list_1 = pd.read_csv(f"{DATA_PATH}AD_LIST_1.csv")
ad_list_2 = pd.read_csv(f"{DATA_PATH}AD_LIST_2.csv")
no_ad_list_lst_1 = pd.read_csv(f"{DATA_PATH}NO_AD_LIST_LST_1.csv")
no_ad_list_lst_2 = pd.read_csv(f"{DATA_PATH}NO_AD_LIST_LST_2.csv")
no_ad_list_str_1 = pd.read_csv(f"{DATA_PATH}NO_AD_LIST_STR_1.csv")
no_ad_list_str_2 = pd.read_csv(f"{DATA_PATH}NO_AD_LIST_STR_2.csv")

# %%
ad_list_1 = ad_list_1.merge(influencer_list_1.loc[:, ['ID', '분야']], left_on='id', right_on='ID', how='left')
ad_list_1 = ad_list_1.drop(columns=['ID'])
ad_list_1
# Out:
#                                                  content  \
# 0       @brmud_official 제 뽀얀(?) 피부의 비결,,,올리브영 1등 마스크팩...
# 1       @lolarose 5월 12일 한국에 새롭게 출시한 롤라로즈 !단풍잎 모양이 넘 ...
# 2       @hassoul_official 편한데 스타일리한 해즈소울~~~제가 사용한 심리스...
# 3       리버클래시 파격 프로모션 주목‼️리버클래시는 자유로운 뜻의 'Liberl'과 고급...
# 4       @clarinskorea 여름철 안티에이징 제품으로 선택한 클라랑스 에센스&아이크...
# ...                                                  ...
# 11472  제품제공 l 퍼펙트풋필링키트🦶돌아온 쓰레빠의  계절🌞🏝️아직도 발 각질정리안하셨다면...
# 11473   🦷임플란트 7년차😳😳구강관리와 치아관리에 진심인 쉐램🙋🏻양치후에도 티클픽플러스로 ...
# 11474   살더미에 마음도 같이 타들어가는중..🌚딱 적절한 운동,식단으로 관리중인데4월부터시...
# 11475   리본코드삭스 너므 귀욥짜나 🩷🖤사진찍을때마다 킹받는 멀티탭,충전기🔌이뿌게 옷 입혀...
# 11476   자고로 장비빨 템팔🤩자동 그라인더로 후추 갈갈 뿌려주니손목스냅 바운스 없이 넘나 ...
#
#                                                 username  \
# 0      ['_sweet_guy._', 'piano_salmon', 'avant__dh', ...
# 1                                                ['nan']
# 2      ['merryzzy', 'bini._.9', 'ricklee504', 'it._.z...
# ...

# %%
ad_list_2 = ad_list_2.merge(influencer_list_2.loc[:, ['ID', '분야']], left_on='id', right_on='ID', how='left')
ad_list_2 = ad_list_2.drop(columns=['ID'])
ad_list_2
# Out:
#                                                  content  \
# 0       딸아이가 너무나 좋아하는 캐치 티니핑으로 영어와 한글 공부를 할 수 있는 학습기가...
# 1       요즘 날씨가 정말 너무 좋아져서!!한 낮에 기분 좋게 나와 햇살도 즐겼어요~~ㅎㅎ...
# 2       이제는 배달비도 그렇고 음식 값이 너무나 올라서 맛있는 야식을 포기하고 있는 분들...
# 3       아이가 가면갈수록 초등수학을 어려워하는 것 같아서 어떻게 하면 아이라 어려워하는 ...
# 4       낮부터 밤까지 여름을 더 쿨하게 즐기는 방법! 의 여름 여행지 BEST9💙👓☀  ...
# ...                                                  ...
# 14997  이번 대만 여행에 함께한  *광고여행을 자주 다니는 만큼캐리어는 꼭 튼튼하고 가벼운...
# 14998  서울 근교 힐링 포인트 비스타밸리 속  *광고푸릇푸릇한 자연 풍경이 함께하는 남양주...
# 14999  여기가 카페야 고깃집이야 🫢.. 🌴🧡새로 오픈한 별돈별 서귀포 중문귤밭점 🍊넓고 큰...
# 15000  여행의 9할을 차지한다고 해도 과언이 아닌 숙소!카셰어링 서비스 쏘카에서 숙박 예약...
# 15001  안동스러운 한옥 자쿠지 숙소 숙박권 이벤트 💌들어가는 순간부터 마음이 편안해지는 안...
#
#                                                 username  \
# 0      ['soraflore_', 'lady007._', 'haha_camping', 'f...
# 1      ['yestobi', 'sinae44', 'eaum0801', 'hyunny01',...
# 2      ['haha_camping', 'foodmin123', 'euphoria.no1',...
# ...

# %%
no_ad_list_lst_1 = no_ad_list_lst_1.merge(influencer_list_2.loc[:, ['ID', '분야']], left_on='id', right_on='ID', how='left')
no_ad_list_lst_1 = no_ad_list_lst_1.drop(columns=['ID'])

no_ad_list_lst_2 = no_ad_list_lst_2.merge(influencer_list_2.loc[:, ['ID', '분야']], left_on='id', right_on='ID', how='left')
no_ad_list_lst_2 = no_ad_list_lst_2.drop(columns=['ID'])

no_ad_list_str_1 = no_ad_list_str_1.merge(influencer_list_2.loc[:, ['ID', '분야']], left_on='id', right_on='ID', how='left')
no_ad_list_str_1 = no_ad_list_str_1.drop(columns=['ID'])

no_ad_list_str_2 = no_ad_list_str_2.merge(influencer_list_2.loc[:, ['ID', '분야']], left_on='id', right_on='ID', how='left')
no_ad_list_str_2 = no_ad_list_str_2.drop(columns=['ID'])

# %%
pd.concat([ad_list_1, ad_list_2])
# Out:
#                                                  content  \
# 0       @brmud_official 제 뽀얀(?) 피부의 비결,,,올리브영 1등 마스크팩...
# 1       @lolarose 5월 12일 한국에 새롭게 출시한 롤라로즈 !단풍잎 모양이 넘 ...
# 2       @hassoul_official 편한데 스타일리한 해즈소울~~~제가 사용한 심리스...
# 3       리버클래시 파격 프로모션 주목‼️리버클래시는 자유로운 뜻의 'Liberl'과 고급...
# 4       @clarinskorea 여름철 안티에이징 제품으로 선택한 클라랑스 에센스&아이크...
# ...                                                  ...
# 14997  이번 대만 여행에 함께한  *광고여행을 자주 다니는 만큼캐리어는 꼭 튼튼하고 가벼운...
# 14998  서울 근교 힐링 포인트 비스타밸리 속  *광고푸릇푸릇한 자연 풍경이 함께하는 남양주...
# 14999  여기가 카페야 고깃집이야 🫢.. 🌴🧡새로 오픈한 별돈별 서귀포 중문귤밭점 🍊넓고 큰...
# 15000  여행의 9할을 차지한다고 해도 과언이 아닌 숙소!카셰어링 서비스 쏘카에서 숙박 예약...
# 15001  안동스러운 한옥 자쿠지 숙소 숙박권 이벤트 💌들어가는 순간부터 마음이 편안해지는 안...
#
#                                                 username  \
# 0      ['_sweet_guy._', 'piano_salmon', 'avant__dh', ...
# 1                                                ['nan']
# 2      ['merryzzy', 'bini._.9', 'ricklee504', 'it._.z...
# ...

# %%
train.to_csv(f"{DATA_PATH}train.csv", index=False)
